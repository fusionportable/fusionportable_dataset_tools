# %%
import os, sys
import subprocess
import matplotlib.pyplot as plt
import numpy as np
import re

FOLDER_PATH = os.path.abspath("")
sys.path.append(os.path.join(FOLDER_PATH, '../..'))
from acquire_color_list import color_list

# %% [markdown]
# #legged_room00  3.01
# #legged_grass00 3.37
# #legged_grass01 3.49
# #legged_transition00 3.36
# #legged_tunnel00 3.31
# #handheld_grass00 -0.23
# #handheld_room00 -0.72
# #handheld_room01 -0.73
# #handheld_starbucks00 -0.64
# #handheld_starbucks01 -0.67
# #handheld_tunnel00 3.2
# #ugv_transition00 0.02
# #ugv_transition01 0.06

# %%
# 初始化参数
t_offset_values = [i * 0.01 for i in range(-150, 50)]  # 从-0.5到0.5，步长为0.1
#t_offset_values = [i * 0.1 for i in range(-20, 40)]  # 从-0.5到0.5，步长为0.1
results = []

# %%
# 循环执行命令
for t_offset in t_offset_values:
    command = [
        'evo_ape', 'tum',
        os.path.join(FOLDER_PATH, 'resampled/handheld_escalator00_resampled.txt'),
        os.path.join(FOLDER_PATH, 'fastlio2/laptop/traj/handheld_escalator00_fastlio2.txt'), 
        '-a', '--t_max_diff', '0.1', '--t_offset', str(t_offset)
    ]
    #print(command)
    process = subprocess.run(command, capture_output=True, text=True)
    
    # 首先打印完整的命令输出
    output = process.stdout
    #print(f"Command output at t_offset {t_offset}:\n{output}")
    
    # 然后解析输出以提取APE的RMSE值
    match = re.search(r"rmse\s+(\d+\.\d+)", output)  # 使用正则表达式匹配RMSE值
    if match:
        ape_rmse = float(match.group(1))
        results.append(ape_rmse)
        print(f"Extracted RMSE: {ape_rmse} at {t_offset}")
    else:
        results.append(None)  # 如果未找到匹配项，添加None
        print("RMSE value not found.")
# Out:
# Extracted RMSE: 0.442426 at -1.5
# Extracted RMSE: 0.440115 at -1.49
# Extracted RMSE: 0.433249 at -1.48
# Extracted RMSE: 0.423356 at -1.47
# Extracted RMSE: 0.421082 at -1.46
# Extracted RMSE: 0.418254 at -1.45
# Extracted RMSE: 0.415386 at -1.44
# Extracted RMSE: 0.407757 at -1.43
# Extracted RMSE: 0.397568 at -1.42
# Extracted RMSE: 0.395322 at -1.41
# Extracted RMSE: 0.392677 at -1.4000000000000001
# Extracted RMSE: 0.38988 at -1.3900000000000001
# Extracted RMSE: 0.38206 at -1.3800000000000001
# Extracted RMSE: 0.373434 at -1.37
# Extracted RMSE: 0.370856 at -1.36
# Extracted RMSE: 0.367884 at -1.35
# Extracted RMSE: 0.365428 at -1.34
# Extracted RMSE: 0.357742 at -1.33
# Extracted RMSE: 0.347511 at -1.32
# Extracted RMSE: 0.345199 at -1.31
# Extracted RMSE: 0.342498 at -1.3
# Extracted RMSE: 0.340175 at -1.29
# Extracted RMSE: 0.333225 at -1.28
# Extracted RMSE: 0.323448 at -1.27
# Extracted RMSE: 0.320832 at -1.26
# Extracted RMSE: 0.318603 at -1.25
# Extracted RMSE: 0.315763 at -1.24
# Extracted RMSE: 0.307688 at -1.23
# Extracted RMSE: 0.297559 at -1.22
# Extracted RMSE: 0.295256 at -1.21
# Extracted RMSE: 0.29346 at -1.2
# Extracted RMSE: 0.290447 at -1.19
# Extracted RMSE: 0.282118 at -1.18
# Extracted RMSE: 0.27384 at -1.17
# Extracted RMSE: 0.271407 at -1.16
# Extracted RMSE: 0.268901 at -1.1500000000000001
# Extracted RMSE: 0.266403 at -1.1400000000000001
# Extracted RMSE: 0.258339 at -1.1300000000000001
# Extracted RMSE: 0.248356 at -1.12
# Extracted RMSE: 0.24629 at -1.11
# Extracted RMSE: 0.244007 at -1.1
# Extracted RMSE: 0.241446 at -1.09
# Extracted RMSE: 0.233491 at -1.08
# Extracted RMSE: 0.225243 at -1.07
# Extracted RMSE: 0.223103 at -1.06
# Extracted RMSE: 0.221343 at -1.05
# Extracted RMSE: 0.218036 at -1.04
# Extracted RMSE: 0.210519 at -1.03
# Extracted RMSE: 0.200914 at -1.02
# Extracted RMSE: 0.198554 at -1.01
# Extracted RMSE: 0.196949 at -1.0
# Extracted RMSE: 0.19412 at -0.99
# Extracted RMSE: 0.186786 at -0.98
# Extracted RMSE: 0.178331 at -0.97
# Extracted RMSE: 0.176582 at -0.96
# Extracted RMSE: 0.174287 at -0.9500000000000001
# Extracted RMSE: 0.171786 at -0.9400000000000001
# Extracted RMSE: 0.164917 at -0.93
# Extracted RMSE: 0.155075 at -0.92
# Extracted RMSE: 0.153403 at -0.91
# Extracted RMSE: 0.151489 at -0.9
# Extracted RMSE: 0.149239 at -0.89
# Extracted RMSE: 0.142746 at -0.88
# Extracted RMSE: 0.135625 at -0.87
# Extracted RMSE: 0.134024 at -0.86
# Extracted RMSE: 0.131257 at -0.85
# Extracted RMSE: 0.12954 at -0.84
# Extracted RMSE: 0.123895 at -0.8300000000000001
# Extracted RMSE: 0.115452 at -0.8200000000000001
# Extracted RMSE: 0.11417 at -0.81
# Extracted RMSE: 0.112023 at -0.8
# Extracted RMSE: 0.110623 at -0.79
# Extracted RMSE: 0.105806 at -0.78
# Extracted RMSE: 0.10144 at -0.77
# Extracted RMSE: 0.100434 at -0.76
# Extracted RMSE: 0.099042 at -0.75
# Extracted RMSE: 0.096853 at -0.74
# Extracted RMSE: 0.093609 at -0.73
# Extracted RMSE: 0.089168 at -0.72
# Extracted RMSE: 0.088572 at -0.71
# Extracted RMSE: 0.087886 at -0.7000000000000001
# Extracted RMSE: 0.08678 at -0.6900000000000001
# Extracted RMSE: 0.08586 at -0.68
# Extracted RMSE: 0.086947 at -0.67
# Extracted RMSE: 0.086922 at -0.66
# Extracted RMSE: 0.086866 at -0.65
# Extracted RMSE: 0.085515 at -0.64
# Extracted RMSE: 0.087214 at -0.63
# Extracted RMSE: 0.089069 at -0.62
# Extracted RMSE: 0.0896 at -0.61
# Extracted RMSE: 0.090045 at -0.6
# Extracted RMSE: 0.090344 at -0.59
# Extracted RMSE: 0.094327 at -0.58
# Extracted RMSE: 0.099371 at -0.5700000000000001
# Extracted RMSE: 0.101682 at -0.56
# Extracted RMSE: 0.101433 at -0.55
# Extracted RMSE: 0.102679 at -0.54
# Extracted RMSE: 0.108013 at -0.53
# Extracted RMSE: 0.114677 at -0.52
# Extracted RMSE: 0.116048 at -0.51
# Extracted RMSE: 0.116667 at -0.5
# Extracted RMSE: 0.118581 at -0.49
# Extracted RMSE: 0.124666 at -0.48
# Extracted RMSE: 0.133888 at -0.47000000000000003
# Extracted RMSE: 0.135421 at -0.46
# Extracted RMSE: 0.136414 at -0.45
# Extracted RMSE: 0.137801 at -0.44
# Extracted RMSE: 0.144387 at -0.43
# Extracted RMSE: 0.153508 at -0.42
# Extracted RMSE: 0.155243 at -0.41000000000000003
# Extracted RMSE: 0.156625 at -0.4
# Extracted RMSE: 0.158634 at -0.39
# Extracted RMSE: 0.165635 at -0.38
# Extracted RMSE: 0.175669 at -0.37
# Extracted RMSE: 0.177408 at -0.36
# Extracted RMSE: 0.178478 at -0.35000000000000003
# Extracted RMSE: 0.180742 at -0.34
# Extracted RMSE: 0.187973 at -0.33
# Extracted RMSE: 0.197725 at -0.32
# Extracted RMSE: 0.199581 at -0.31
# Extracted RMSE: 0.20118 at -0.3
# Extracted RMSE: 0.203675 at -0.29
# Extracted RMSE: 0.211031 at -0.28
# Extracted RMSE: 0.221208 at -0.27
# Extracted RMSE: 0.222955 at -0.26
# Extracted RMSE: 0.224709 at -0.25
# Extracted RMSE: 0.226964 at -0.24
# Extracted RMSE: 0.234297 at -0.23
# Extracted RMSE: 0.244655 at -0.22
# Extracted RMSE: 0.246412 at -0.21
# Extracted RMSE: 0.248303 at -0.2
# Extracted RMSE: 0.250857 at -0.19
# Extracted RMSE: 0.258108 at -0.18
# Extracted RMSE: 0.268513 at -0.17
# Extracted RMSE: 0.270268 at -0.16
# Extracted RMSE: 0.272107 at -0.15
# Extracted RMSE: 0.274579 at -0.14
# Extracted RMSE: 0.281867 at -0.13
# Extracted RMSE: 0.292502 at -0.12
# Extracted RMSE: 0.29437 at -0.11
# Extracted RMSE: 0.296264 at -0.1
# Extracted RMSE: 0.298925 at -0.09
# Extracted RMSE: 0.306142 at -0.08
# Extracted RMSE: 0.316799 at -0.07
# Extracted RMSE: 0.318527 at -0.06
# Extracted RMSE: 0.320266 at -0.05
# Extracted RMSE: 0.322831 at -0.04
# Extracted RMSE: 0.330294 at -0.03
# Extracted RMSE: 0.340951 at -0.02
# Extracted RMSE: 0.34288 at -0.01
# Extracted RMSE: 0.344768 at 0.0
# Extracted RMSE: 0.347285 at 0.01
# Extracted RMSE: 0.354894 at 0.02
# Extracted RMSE: 0.365409 at 0.03
# Extracted RMSE: 0.367259 at 0.04
# Extracted RMSE: 0.368886 at 0.05
# Extracted RMSE: 0.371404 at 0.06
# Extracted RMSE: 0.379097 at 0.07
# Extracted RMSE: 0.389774 at 0.08
# Extracted RMSE: 0.391595 at 0.09
# Extracted RMSE: 0.393308 at 0.1
# Extracted RMSE: 0.396106 at 0.11
# Extracted RMSE: 0.403783 at 0.12
# Extracted RMSE: 0.414251 at 0.13
# Extracted RMSE: 0.415729 at 0.14
# Extracted RMSE: 0.417388 at 0.15
# Extracted RMSE: 0.420229 at 0.16
# Extracted RMSE: 0.428016 at 0.17
# Extracted RMSE: 0.438664 at 0.18
# Extracted RMSE: 0.440604 at 0.19
# Extracted RMSE: 0.442139 at 0.2
# Extracted RMSE: 0.444919 at 0.21
# Extracted RMSE: 0.452383 at 0.22
# Extracted RMSE: 0.462974 at 0.23
# Extracted RMSE: 0.464531 at 0.24
# Extracted RMSE: 0.466212 at 0.25
# Extracted RMSE: 0.468969 at 0.26
# Extracted RMSE: 0.476471 at 0.27
# Extracted RMSE: 0.487482 at 0.28
# Extracted RMSE: 0.489508 at 0.29
# Extracted RMSE: 0.490886 at 0.3
# Extracted RMSE: 0.493632 at 0.31
# Extracted RMSE: 0.501292 at 0.32
# Extracted RMSE: 0.511717 at 0.33
# Extracted RMSE: 0.513356 at 0.34
# Extracted RMSE: 0.514947 at 0.35000000000000003
# Extracted RMSE: 0.517729 at 0.36
# Extracted RMSE: 0.525479 at 0.37
# Extracted RMSE: 0.53624 at 0.38
# Extracted RMSE: 0.538374 at 0.39
# Extracted RMSE: 0.53963 at 0.4
# Extracted RMSE: 0.542426 at 0.41000000000000003
# Extracted RMSE: 0.550172 at 0.42
# Extracted RMSE: 0.560487 at 0.43
# Extracted RMSE: 0.562122 at 0.44
# Extracted RMSE: 0.563786 at 0.45
# Extracted RMSE: 0.566697 at 0.46
# Extracted RMSE: 0.574285 at 0.47000000000000003
# Extracted RMSE: 0.584872 at 0.48
# Extracted RMSE: 0.587117 at 0.49

# %% [markdown]
# # 绘制结果
# plt.figure(figsize=(10, 6))
# plt.plot(t_offset_values, results, marker='o')
# plt.title('APE Mean vs. Time Offset')
# plt.xlabel('Time Offset (s)')
# plt.ylabel('APE Mean')
# plt.grid(True)
# plt.show()

# %%
# 找出 RMSE 最小值及其对应的 t_offset
min_rmse = min(results)  # 假设 results 中没有 None 值
min_rmse_index = results.index(min_rmse)
min_rmse_offset = t_offset_values[min_rmse_index]
print(f" The minimum offset is {min_rmse_offset}")
# Out:
#  The minimum offset is -0.64

# %%
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.weight'] = 'normal'
plt.rcParams['axes.labelweight'] = 'normal'
plt.rcParams['axes.titleweight'] = 'normal'

# 绘制 RMSE 曲线
plt.figure(figsize=(8,3))
# plt.plot(t_offset_values, results, color=color_list[0][:3], marker='*', label='ATE', markersize=3, linestyle='None')
plt.plot(t_offset_values, results, color=color_list[0][:3], label='ATE', markersize=3, linewidth=2)
# 标记 RMSE 最小值的点
plt.scatter(min_rmse_offset, min_rmse, color=color_list[1][:3], s=100, label='Minimum ATE', zorder=5)
# 在标记点上添加注释显示对应的 t_offset 值
plt.annotate(f"Optimal Offset\n {min_rmse_offset}s", 
             (min_rmse_offset, min_rmse),
             textcoords="offset points", 
             xytext=(198,0), 
             ha='center',
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.1"),
             fontsize=15)
#Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.serif'] = 'Times New Roman'
plt.rcParams['font.size'] = 20
plt.xlabel('Time Offset [s]')
plt.ylabel('ATE')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05), ncol=2, fontsize=15)
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(FOLDER_PATH, 'correlation.pdf'), format='pdf')
plt.show()
